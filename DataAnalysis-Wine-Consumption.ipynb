# %%
import pandas as pd 
import requests
from bs4 import BeautifulSoup
import re

# %%
import requests

# 1. Define where the data is (The URL)
url = "https://wine-explorer-api-ratings-insights-and-search.p.rapidapi.com/info"

# 2. Set your search parameters (The ID you want to find)
querystring = {"_id": "6714ce76443fd8fa014b6441"}

# 3. Add your 'Passport' (The Headers)
headers = {
    "X-RapidAPI-Key": "ee2ae08933msh16e1dc1071fd39cp16e359jsn58c7dd87b447",
    "X-RapidAPI-Host": "wine-explorer-api-ratings-insights-and-search.p.rapidapi.com"
}

# 4. Make the request and store it in a variable called 'response'
response = requests.get(url, headers=headers, params=querystring)

# 5. Print the result as clean JSON data
print(response.json())
# Out:
# {'winery': {'name': 'Domaine de Régusse', 'seo_name': 'sarl-cave-et-vignobles-de-regusse', 'review_status': 'Completed', 'region': {'country': 'fr', 'parent_id': None, 'name': 'Provence', 'seo_name': 'provence', 'name_en': '', 'statistics': {'wineries_count': 1635, 'sub_regions_count': 9, 'parent_regions_count': 0, 'wines_count': 9340}}, 'status': 0, 'statistics': {'ratings_average': 3.7, 'labels_count': 39217, 'ratings_count': 3932, 'wines_count': 47}}, 'statistics': {'ratings_average': 0, 'labels_count': 12, 'ratings_count': 2, 'status': 'BelowThreshold', 'vintages_count': 9}, 'is_natural': False, 'vintages': [{'name': 'Domaine de Régusse Syrah 2019', 'seo_name': 'sarl-cave-et-vignobles-de-regusse-syrah-2019', 'year': '2019', 'statistics': {'ratings_average': 0, 'labels_count': 0, 'ratings_count': 0, 'status': 'BelowThreshold', 'reviews_count': 0}}, {'name': 'Domaine de Régusse Syrah 2018', 'seo_name': 'sarl-cave-et-vignobles-de-regusse-syrah-2018', 'year': '2018', 'statistics': {'
# ...

# %%
soup = BeautifulSoup(response.content, "html.parser")
soup
# Out:
# {"winery": {"name": "Domaine de R\u00e9gusse", "seo_name": "sarl-cave-et-vignobles-de-regusse", "review_status": "Completed", "region": {"country": "fr", "parent_id": null, "name": "Provence", "seo_name": "provence", "name_en": "", "statistics": {"wineries_count": 1635, "sub_regions_count": 9, "parent_regions_count": 0, "wines_count": 9340}}, "status": 0, "statistics": {"ratings_average": 3.7, "labels_count": 39217, "ratings_count": 3932, "wines_count": 47}}, "statistics": {"ratings_average": 0, "labels_count": 12, "ratings_count": 2, "status": "BelowThreshold", "vintages_count": 9}, "is_natural": false, "vintages": [{"name": "Domaine de R\u00e9gusse Syrah 2019", "seo_name": "sarl-cave-et-vignobles-de-regusse-syrah-2019", "year": "2019", "statistics": {"ratings_average": 0, "labels_count": 0, "ratings_count": 0, "status": "BelowThreshold", "reviews_count": 0}}, {"name": "Domaine de R\u00e9gusse Syrah 2018", "seo_name": "sarl-cave-et-vignobles-de-regusse-syrah-2018", "year": "2018", "
# ...

# %%
#Dataset 1 available 

df1 = pd.read_csv("/Users/Helena/Documents/GitHub/Wine-Consumption/archive/winemag-data_first150k.csv")
pd.options.display.max_columns = None  
df1.head()
# Out:
#    Unnamed: 0 country                                        description  \
# 0           0      US  This tremendous 100% varietal wine hails from ...
# 1           1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           2      US  Mac Watson honors the memory of a wine once ma...
# 3           3      US  This spent 20 months in 30% new French oak, an...
# 4           4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# ...

# %%
#Dataset 2 available #this dataset has the title/name of the wine and the other one above doesn'T, TITLE could be useful to concatenate/merge data coming from the API

df3= pd.read_csv("/Users/Helena/Documents/GitHub/Wine-Consumption/archive/winemag-data-130k-v2.csv")
pd.options.display.max_columns = None  
df3.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
#new data set I found which could be useful if API does not have common columns/values to be matched with (aditional one)

df2= pd.read_csv("/Users/Helena/Documents/GitHub/Wine-Consumption/WineDataset.csv")

pd.options.display.max_columns = None  
df2.head()
# Out:
#                                                Title  \
# 0                                 The Guv'nor, Spain
# 1  Bread & Butter 'Winemaker's Selection' Chardon...
# 2       Oyster Bay Sauvignon Blanc 2022, Marlborough
# 3                   Louis Latour Mâcon-Lugny 2021/22
# 4  Bread & Butter 'Winemaker's Selection' Pinot N...
#
#                                          Description              Price  \
# 0  We asked some of our most prized winemakers wo...   £9.99 per bottle
# 1  This really does what it says on the tin. It’s...  £15.99 per bottle
# 2  Oyster Bay has been an award-winning gold-stan...  £12.49 per bottle
# 3  We’ve sold this wine for thirty years – and fo...  £17.99 per bottle
# 4  Bread & Butter is that thing that you can coun...  £15.99 per bottle
#
#   Capacity            Grape Secondary Grape Varieties       Closure  \
# 0     75CL      Tempranillo                       NaN  Natural Cork
# 1     75CL       Chardonnay                       NaN  Natural Cork
# ...
